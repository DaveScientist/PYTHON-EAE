# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Python Basics II Exercises

# %% [markdown]
# ## Exercise 1
# * Create two numeric variables: an `int` and a `float`
# * Check their types
# * Add them in another new variable
# * What type is the new variable?
# * Delete the first two variables created

# %%
var1 = 10
var2 = 8.5
print(type(var1))
print(type(var2))
#print(type(var1), type(var2))

var3 = float(var1) + var2
print(var3)
type(var3)
del(var1)
del(var2)

#print(var1)
# Out:
# <class 'int'>
# <class 'float'>
# 18.5

# %% [markdown]
# ## Exercise 2
# Write a program to convert degrees to radians. You must use `input`. Remember that the conversion is done through
#
# radians = degrees*(pi/180)

# %%
#radians = float(input())
degrees = float(input("tell the degress: "))
from math import pi
radians = degrees*pi/180

# %%
from math import pi
print(pi)
degrees = float(input("insert the degree: "))
radians = degrees *(pi/180)
print(radians)
# Out:
# 3.141592653589793
# 0.08726646259971647

# %% [markdown]
# ## Exercise 3
# Write a program that calculates the area of a parallelogram (base x height). Also with `input`

# %%
base = int(input())
height = int(input())
area = base * height
print(area)
# Out:
# 20

# %% [markdown]
# ## Exercise 4
# We have the following variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Check:
# 1. If A and B are equivalent
# 2. If A and C are NOT equivalent
# 3. If A is greater than C
# 4. If C is less than or equal to A
# 5. If B is NOT equivalent to C

# %%
a = 4
b = "text"
c = 4.1
print(a == b)
print(a != c)
print(a >= c)
print(c <= a)
print(b != c)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# ## Exercise 5
# Create a program where two user inputs are collected, and the program output is whether those inputs are equal or not

# %%
var4 = input("Insert first number:")
var5 = input("Insert second number:")
print(var4==var5)
# Out:
# False

# %% [markdown]
# ## Exercise 6
# Same program as in 5, but this time there must be three inputs and two outputs. One output should tell us if all are equal, and the other if at least two inputs are equal

# %%
var6 = input()
var7 = input()
var8 = input()
print(var6==var7==var8)
if var6==var7 or var7==var8 or var6==var8:
    print("Numbers are Equals")

print("are the numbers equal?", var6==var7 and var7==var8)
# Out:
# False
# Numbers are Equals
# are the numbers equal? False

# %% [markdown]
# ## Exercise 7
# Create a program that takes two inputs. It must check if their sum is equal, greater than, or less than 10

# %%
variable1 = int(input())
variable2 = int(input())
if (variable1 + variable2)==10:
    print("Equal 10")
elif (variable1 + variable2)>10:
    print("Greater than 10")
elif (variable1 + variable2)<10:
    print("less than 10")
# Out:
# less than 10

# %% [markdown]
# ## Exercise 8
# Reason without executing code what output we will get from the following statements
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1. False
# 2. False
# 3. False
# 4. False

# %% [markdown]
# ## Exercise 9
# For this exercise we are going to practice [built-in functions](https://docs.python.org/3/library/functions.html).
#
# 1. Calculate the maximum of the list: [4, 6, 8, -1]
# 2. Sum all elements of the previous list
# 3. Round this float to 3 decimal digits: 63.451256965
# 4. Absolute value of: -74

# %%
lista = [4, 6, 8, -1]

maximo = max(lista)
print(maximo)
print(sum(lista))
# Out:
# 8
# 17

# %%
numero = 63.451
print(round(numero, 3))

valor = -74
print(abs(valor))
# Out:
# 63.451
# 74

# %% [markdown]
# ## Exercise 10
# For the following string you are asked to print the following cases on screen
#
#     "Early birds catch the worm"
#
# 1. Convert it all to uppercase
# 2. Convert it all to lowercase
# 3. Convert to uppercase only the initial of the words
# 4. Create a list by dividing it by its spaces
# 5. Replace commas `,` with semicolons `;`
# 6. Remove lowercase `a` letters

# %%
Frase = "Early birds catch the worm"
print(Frase.upper())
print(Frase.lower())
print(Frase.title())
print(Frase.split())
print(Frase.replace(",", ";"))
print(Frase.replace("a", " "))
# Out:
# EARLY BIRDS CATCH THE WORM
# early birds catch the worm
# Early Birds Catch The Worm
# ['Early', 'birds', 'catch', 'the', 'worm']
# Early birds catch the worm
# E rly birds c tch the worm

# %% [markdown]
# ## Exercise 11
# 1. Create a list with 3 numeric elements
# 2. Add a fourth element
# 3. Calculate the sum of all
# 4. Delete the second element of the list
# 5. Add another element at position 3 of the list
# 6. Create another list with 4 elements and concatenate it to the one you already had.

# %%
listaaa = [5,7,9]
print(listaaa.append(11))
print(listaaa)
print(sum(listaaa))
del listaaa[1]
print(listaaa)

lista2 = [4,5]
lista3 = lista2 + listaaa
print(lista3)
# Out:
# None
# [5, 7, 9, 11]
# 32
# [5, 9, 11]
# [4, 5, 5, 9, 11]

# %%
lista2 = [5, 9, 13]
print(lista2)
lista2.append(8)
print(lista2)
print(sum(lista2))

del lista2[1]
print(lista2)

lista2.insert(2, 10)
print(lista2)

lista3 = [11, 12, 13]
nuevalista = lista2 + lista3
print(nuevalista)
# Out:
# [5, 9, 13]
# [5, 9, 13, 8]
# 35
# [5, 13, 8]
# [5, 13, 10, 8]
# [5, 13, 10, 8, 11, 12, 13]
